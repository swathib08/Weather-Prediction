# %% [markdown]
# <a href="https://colab.research.google.com/github/swathib08/Weather-Prediction/blob/main/Weather_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd 
from mpl_toolkits.mplot3d import Axes3D
from google.colab import files
uploaded = files.upload()
import io
dataset = pd.read_csv(io.BytesIO(uploaded['weather.csv']))
# Out:
#      <input type="file" id="files-49160ba6-79ff-4f5c-a733-e88c7cf8c87e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49160ba6-79ff-4f5c-a733-e88c7cf8c87e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv

# %%
nRowsRead = 1000 
df1 = pd.read_csv('weather.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'weather.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
df1.head(5)
df1.plot.bar(x='Rainfall' ,y = 'Sunshine')
df1.plot.scatter(x = 'Rainfall',y = 'Sunshine',alpha= 0.5)
plt.show()
# Out:
# There are 366 rows and 22 columns
